# %% [markdown]
# # Press Run

# %%
# !./tipars -t 'Benchmark\ datasets/H3N2/H3N2_tree.nwk' -s 'Benchmark\ datasets/H3N2/H3N2_taxa.fas' -q 'Benchmark\ datasets/H3N2/H3N2_query.fas' -a 'Benchmark\ datasets/H3N2/H3N2_anc.fas' -o tipars-H3N2.nwk
# Out:
# query1	*Node631-Node638	ABQ_brlen: 5.916E-4	0.0	5.916E-4
# query2	*Node39-Node101	ABQ_brlen: 0.002362	0.0	0.001181
# query3	*Node945-EPI166290	ABQ_brlen: 0.0035649	0.0	0.0011883
# Insertion time: 0.676
# Overall time: 1.004

# %%
# !./tipars -t 'Benchmark\ datasets/NDV/NDV_tree.nwk' -s 'Benchmark\ datasets/NDV/NDV_taxa.fas' -q 'Benchmark\ datasets/NDV/NDV_query.fas' -a 'Benchmark\ datasets/NDV/NDV_anc.fas' -o tipars-NDV.nwk
# Out:
# query_1	*Node3-JX119193	ABQ_brlen: 0.1192182	0.0	1.4800521415270017E-4
# query_2	*Node175-Node176	ABQ_brlen: 0.020043516819571866	6.148318042813494E-5	6.148318042813456E-5
# Insertion time: 0.351
# Overall time: 0.706
